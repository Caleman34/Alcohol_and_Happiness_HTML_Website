# %%
# import dependencies
import pandas as pd

# import data and use padas to create tables for html format
url = "Resources/group_df.csv"
group_df = pd.read_csv(url)
group_df.head()
# Out:
#        Country          Region  Happiness Score  Beer (Per Capita)  \
# 0      Denmark  Western Europe            7.526                224
# 1  Switzerland  Western Europe            7.509                185
# 2      Iceland  Western Europe            7.501                233
# 3       Norway  Western Europe            7.498                169
# 4      Finland  Western Europe            7.413                263
#
#    Spirit (Per Capita)  Wine (Per Capita)  GDP (Per Capita)  \
# 0                   81                278             1.502
# 1                  100                280             1.566
# 2                   61                 78             1.482
# 3                   71                129             1.543
# 4                  133                 97             1.446
#
#    Perceptions of Corruption  Social Support  Life Choices
# 0                      0.179           1.108         0.686
# 1                      0.292           1.079         0.653
# ...

# %%
# convert pandas df into table formated for html
html_table = group_df.to_html()
html_table
# Out:
# d Caribbean</td>\n      <td>6.068</td>\n      <td>52</td>\n      <td>69</td>\n      <td>2</td>\n      <td>0.845</td>\n      <td>0.688</td>\n      <td>0.675</td>\n      <td>0.615</td>\n    </tr>\n    <tr>\n      <th>38</th>\n      <td>Nicaragua</td>\n      <td>Latin America and Caribbean</td>\n      <td>5.992</td>\n      <td>78</td>\n      <td>118</td>\n      <td>1</td>\n      <td>0.693</td>\n      <td>0.664</td>\n      <td>0.904</td>\n      <td>0.553</td>\n    </tr>\n    <tr>\n      <th>39</th>\n      <td>Uzbekistan</td>\n      <td>Central and Eastern Europe</td>\n      <td>5.987</td>\n      <td>25</td>\n      <td>101</td>\n      <td>8</td>\n      <td>0.769</td>\n      <td>0.515</td>\n      <td>1.027</td>\n      <td>0.716</td>\n    </tr>\n    <tr>\n      <th>40</th>\n      <td>Italy</td>\n      <td>Western Europe</td>\n      <td>5.977</td>\n      <td>85</td>\n      <td>42</td>\n      <td>237</td>\n      <td>1.393</td>\n      <td>0.866</td>\n      <td>0.940</td>\n      <td>0.379</td>\
# ...

# %%
# strip \n to clean up the table
html_table.replace('\n', '')
# Out:
#       <td>76</td>      <td>3</td>      <td>1.021</td>      <td>0.841</td>      <td>0.866</td>      <td>0.554</td>    </tr>    <tr>      <th>30</th>      <td>France</td>      <td>Western Europe</td>      <td>6.478</td>      <td>127</td>      <td>151</td>      <td>370</td>      <td>1.421</td>      <td>0.571</td>      <td>1.081</td>      <td>0.536</td>    </tr>    <tr>      <th>31</th>      <td>Thailand</td>      <td>Southeastern Asia</td>      <td>6.474</td>      <td>99</td>      <td>258</td>      <td>1</td>      <td>1.107</td>      <td>0.895</td>      <td>0.957</td>      <td>0.611</td>    </tr>    <tr>      <th>32</th>      <td>Spain</td>      <td>Western Europe</td>      <td>6.361</td>      <td>284</td>      <td>157</td>      <td>112</td>      <td>1.375</td>      <td>0.745</td>      <td>1.057</td>      <td>0.462</td>    </tr>    <tr>      <th>33</th>      <td>Guatemala</td>      <td>Latin America and Caribbean</td>      <td>6.324</td>      <td>53</td>      <td>69</td>      <td>2</td>
# ...

# %%
# save table to a file
tables.to_html('table.html')
